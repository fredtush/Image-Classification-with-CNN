# %% [markdown]
# # IMAGE CLASSIFICATION WITH DEEP LEARNING
#
# ## Business understanding
#
# # Data Analytic Question
#
# ## Problem Statement
#
# Tibabu Hospital did a research on the accuracy of Pneumonia diagnosis. The the results were  not impressive. So to improve diagnosis of pneumonia using x-rays, tasked us to come up with a solution.
# Our task is to come up with a classification algorithm that will determine if a patient has pneumonia or not based on chest X-ray images.
#
#
# ## Context
#
# ## Metric of Success
# We want our algorithm that makes predictions with have a root mean squared error (RMSE) of between 0.2 and 0.5 (with an of Accuracy: 86%-90%).
#
# ## Data Undersatnding
# The medical dataset comes from Kaggle contains a set of x-ray images of pediatric patients. The images will show whether the patients have pneumonia or not. Our task is to build a model that can classify whether a given patient has pneumonia given a chest x-ray image. Since this is an Image Classification problem, we will solve it with Deep Learning.
#
#
# ## The Dataset
# The dataset that we will use for image classification is the chese_xray which contains two categories: Pneumonia and Normal. The data will be downloaded from https://www.kaggle.com/datasets/paultimothymooney/chest-xray-pneumonia to the local drive and unzipped. The data set will be assigned two folders (train and test) and contains a subfolder for each Pneumonia and Normal category.
# In each of the folders, there are a lot of x-ray images. To check how many samples were in each category, we will use the OS.listdir methods.
#
#
# ## Plan
#
# 1. Load and Pre-process the data.
# 2. Define the trained generator, validation generator, and test generator.
# 2. Build a baseline model.
# 3. Build the deep learning model base. Then, train the model with selected images.
# 4. Retrain the model with complete training data.
# 5. Evaluate the model with the test images.

# %% [markdown]
# ### Libraries | Modules.
#
# We start by importing all the necessary Libraries | Modules.

# %%
# import all relevant libraries

import numpy as np 
import pandas as pd

# visualization libraries

import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns  

# tensorflow

import os, shutil
import tensorflow as ts
from tensorflow.keras.preprocessing.image import load_img, ImageDataGenerator, array_to_img
from tensorflow.keras import layers
from tensorflow.keras import models
from tensorflow.keras import optimizers

# sklearn
from sklearn.metrics import classification_report,confusion_matrix

# %% [markdown]
# Next we will load the data using `os.listdir` method

# %%
# directory for the chest_xray folder

print(os.listdir('data/chest_xray'))
# Out:
# ['chest_xray', '__MACOSX', 'test', 'val', 'train']

# %% [markdown]
# We stored the data for both normal and pneumonia xray images into variables for easy access. Thi is for our train, test and val data.

# %%
# store train normal xrays and train pneumonia xrays as variables.

train_norm_img = os.listdir('data/chest_xray/chest_xray/train/NORMAL')
train_pneu_img = os.listdir('data/chest_xray/chest_xray/train/PNEUMONIA')

print(np.shape(train_norm_img))
print(np.shape(train_pneu_img))
# Out:
# (1342,)
# (3876,)

# %%
# store train normal xrays and test pneumonia xrays as variables.

test_norm_img = os.listdir('data/chest_xray/chest_xray/test/NORMAL')
test_pneu_img = os.listdir('data/chest_xray/chest_xray/test/PNEUMONIA')

# %%
# store train normal xrays and val pneumonia xrays as variables.

val_norm_img = os.listdir('data/chest_xray/chest_xray/val/NORMAL')
val_pneu_img = os.listdir('data/chest_xray/chest_xray/val/PNEUMONIA')

# %%
# directory for the chest_xray train normal folder
#df = os.listdir('data/chest_xray/__MACOSX/chest_xray/train/NORMAL')

print(os.listdir('data/chest_xray/chest_xray/train/NORMAL'))
# Out:
peg', 'person1544_virus_2685.jpeg', 'person1216_virus_2062.jpeg', 'person295_bacteria_1390.jpeg', 'person313_bacteria_1457.jpeg', 'person629_bacteria_2508.jpeg', 'person1463_virus_2516.jpeg', 'person850_bacteria_2771.jpeg', 'person658_virus_1241.jpeg', 'person465_virus_957.jpeg', 'person372_bacteria_1706.jpeg', 'person1292_bacteria_3255.jpeg', 'person981_virus_1657.jpeg', 'person61_bacteria_297.jpeg', 'person55_bacteria_265.jpeg', 'person1500_bacteria_3916.jpeg', 'person1190_virus_2031.jpeg', 'person565_virus_1105.jpeg', 'person837_virus_1475.jpeg', 'person1045_virus_1741.jpeg', 'person470_bacteria_2000.jpeg', 'person1241_virus_2106.jpeg', 'person776_bacteria_2680.jpeg', 'person677_virus_1268.jpeg', 'person108_virus_200.jpeg', 'person1481_bacteria_3864.jpeg', 'person458_bacteria_1953.jpeg', 'person291_bacteria_1377.jpeg', 'person699_virus_1295.jpeg', 'person1667_bacteria_4417.jpeg', 'person67_bacteria_333.jpeg', 'person60_bacteria_285.jpeg', 'person864_virus_1509.jpeg', 'person1611_bacteria_4241.jpeg', 'person326_virus_666.jpeg', 'person1231_bacteria_3186.jpeg', 'person567_virus_1107.jpeg', 'person1455_virus_2488.jpeg', 'person571_bacteria_2367.jpeg', 'person878_virus_1526.jpeg', 'person36_bacteria_183.jpeg', 'person1037_bacteria_2971.jpeg', 'person1375_bacteria_3510.jpeg', 'person1496_bacteria_3907.jpeg', 'person332_bacteria_1531.jpeg', 'person1556_virus_2699.jpeg', 'person710_bacteria_2611.jpeg', 'person1062_virus_1762.jpeg', 'person371_bacteria_1700.jpeg', 'person1019_virus_1708.jpeg', 'person704_bacteria_2603.jpeg', 'person501_bacteria_2112.jpeg', 'person718_virus_1316.jpeg', 'person1159_virus_1944.jpeg', 'person395_bacteria_1795.jpeg', 'person371_bacteria_1695.jpeg', 'person1102_virus_1822.jpeg', 'person805 ...

# %%
# Display an image from the train NORMAL folder.
#image.ImageDataGenerator()

img_name = 'person7_bacteria_25.jpeg'
pneumonia_lung = load_img('data/chest_xray/chest_xray/train/PNEUMONIA/' + img_name)


print('PNEUMONIA LUNG')
plt.imshow(pneumonia_lung)
plt.show()
# Out:
# PNEUMONIA LUNG

# %% [markdown]
# We went further to explore the shape of both the images and the labels of our training, testing and validation data.

# %%
# preview the shape of train data

print(np.shape(train_norm_img))
print(np.shape(train_pneu_img))
# Out:
# (1342,)
# (3876,)

# %%
# preview the shape of test data

print(np.shape(test_norm_img))
print(np.shape(test_pneu_img))
# Out:
# (234,)
# (390,)

# %%
# preview the shape of val data

print(np.shape(val_norm_img))
print(np.shape(val_pneu_img))
# Out:
# (9,)
# (9,)

# %% [markdown]
# Next we'll do some visualizations for train and test data.
#
# ## Visualizations
#
# ### Training Set

# %%
# combining the train data for plotting visualizations

total_train = train_norm_img + train_pneu_img
print(np.shape(total_train))
# Out:
# (5218,)

# %%
# creating countplot for total_counts_train

total_counts_train = []
pneu_len_train = 0
norm_len_train = 0
for i in total_train:
    if i[0] == 'p':
        total_counts_train.append('Pneumonia')
        pneu_len_train += 1
    elif i[0] == 'N' or i[0] == 'I':
        total_counts_train.append('Normal')
        norm_len_train += 1
        
sns.countplot(total_counts_train);
print('The total count for people without pneumonia is: {}'.format(norm_len_train))
print('----------------------------------------------------------------------------------')
print('The total count for people with for pneuomonia is: {}'.format(pneu_len_train))
# Out:
# /home/dyfrey/anaconda3/lib/python3.9/site-packages/seaborn/_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# The total count for people without pneumonia is: 1341
# ----------------------------------------------------------------------------------
# The total count for people with for pneuomonia is: 3875

# %% [markdown]
# ### Test Set

# %%
# combining the test data for plotting visualizations

total_test = test_norm_img + test_pneu_img
print(np.shape(total_test))
# Out:
# (624,)

# %%
# creating countplot for total_counts_test

total_counts_test= []
pneu_len_test = 0
norm_len_test = 0
for i in total_test:
    if i[0] == 'p':
        total_counts_test.append('Pneumonia')
        pneu_len_test += 1
    elif i[0] == 'N' or i[0] == 'I':
        total_counts_test.append('Normal')
        norm_len_test += 1
        
sns.countplot(total_counts_test);
print('The total count for people without pneumonia is: {}'.format(norm_len_test))
print('----------------------------------------------------------------------------------')
print('The total count for people with for pneuomonia is: {}'.format(pneu_len_test))
# Out:
# The total count for people without pneumonia is: 234
# ----------------------------------------------------------------------------------
# The total count for people with for pneuomonia is: 390
# /home/dyfrey/anaconda3/lib/python3.9/site-packages/seaborn/_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %% [markdown]
# ### Validation Set

# %%
# combining the val data for plotting visualizations

total_val = val_norm_img + val_pneu_img
print(np.shape(total_val))
# Out:
# (18,)

# %%
# creating countplot for total_counts_val

total_counts_val= []
pneu_len_val = 0
norm_len_val = 0
for i in total_val:
    if i[0] == 'p':
        total_counts_val.append('Pneumonia')
        pneu_len_val += 1
    elif i[0] == 'N' or i[0] == 'I':
        total_counts_val.append('Normal')
        norm_len_val += 1
        
sns.countplot(total_counts_val);
print('The total count for people without pneumonia is: {}'.format(norm_len_val))
print('----------------------------------------------------------------------------------')
print('The total count for people with for pneuomonia is: {}'.format(pneu_len_val))
# Out:
# /home/dyfrey/anaconda3/lib/python3.9/site-packages/seaborn/_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# The total count for people without pneumonia is: 8
# ----------------------------------------------------------------------------------
# The total count for people with for pneuomonia is: 8

# %% [markdown]
# ## Reshaping and Normalizing the Data
#
# This step is crucial to provide us with a unform set of data easy to work with during our modelling.

# %%
# first convert our data into array
train = 'data/chest_xray/chest_xray/train'
test = 'data/chest_xray/chest_xray/test'
val = 'data/chest_xray/chest_xray/val'

# %%
# All images will be rescaled by 1./255
train_datagen = ImageDataGenerator(rescale=1./255)
test_datagen = ImageDataGenerator(rescale=1./255)
val_datagen = ImageDataGenerator(rescale=1./255)

train_generator = train_datagen.flow_from_directory(
        # This is the target directory
        train,
        # All images will be resized to 150x150
        target_size=(150, 150),
        batch_size=len(total_train),
        # Since we use binary_crossentropy loss, we need binary labels
        class_mode='binary')
test_generator = test_datagen.flow_from_directory(
        # This is the target directory
        test,
        # All images will be resized to 150x150
        target_size=(150, 150),
        batch_size=len(total_test),
        # Since we use binary_crossentropy loss, we need binary labels
        class_mode='binary')
val_generator = val_datagen.flow_from_directory(
        # This is the target directory
        val,
        # All images will be resized to 150x150
        target_size=(150, 150),
        batch_size=len(total_val),
        # Since we use binary_crossentropy loss, we need binary labels
        class_mode='binary')
# Out:
# Found 5216 images belonging to 2 classes.
# Found 624 images belonging to 2 classes.
# Found 16 images belonging to 2 classes.

# %%
# create new datasets

train_images, train_labels = next(train_generator)
test_images, test_labels = next(test_generator)
val_images, val_labels = next(val_generator)

# %%
# viewing an xray from our new dataset.

array_to_img(train_images[10])
# Out:
# <PIL.Image.Image image mode=RGB size=150x150 at 0x7F167905C0A0>

# %%
# viewing our labels

train_labels
# Out:
# array([1., 0., 0., ..., 0., 1., 0.], dtype=float32)

# %%
# shape of our new data

print('The new train shape is:', train_images.shape)
print('The new test shape is:', test_images.shape)
print('The new val shape is:', val_images.shape)
# Out:
# The new train shape is: (5216, 150, 150, 3)
# The new test shape is: (624, 150, 150, 3)
# The new val shape is: (16, 150, 150, 3)

# %%
# identifying our normal and pneumonia xrays

train_generator.class_indices
# Out:
# {'NORMAL': 0, 'PNEUMONIA': 1}
